# %%
import numpy as np
import datetime
import tensorflow as tf
from tensorflow.keras.datasets import fashion_mnist

# %%
tf.__version__
# Out:
# '2.0.0'

# %%
(X_train, y_train), (X_test, y_test) = fashion_mnist.load_data()

# %%
X_train = X_train / 255.0

# %%
X_test = X_test / 255.0

# %%
X_train = X_train.reshape(-1, 28*28)

# %%
X_train.shape
# Out:
# (60000, 784)

# %%
X_test = X_test.reshape(-1, 28*28)

# %%
model = tf.keras.models.Sequential()
model.add(tf.keras.layers.Dense(units=32, activation='relu', input_shape=(784, )))
model.add(tf.keras.layers.Dropout(0.4))
model.add(tf.keras.layers.Dense(units=64, activation='relu'))
model.add(tf.keras.layers.Dropout(0.6))
model.add(tf.keras.layers.Dense(units=128, activation='relu'))
model.add(tf.keras.layers.Dense(units=10, activation='softmax'))
# Out:
# WARNING:tensorflow:Large dropout rate: 0.6 (>0.5). In TensorFlow 2.x, dropout() uses dropout rate instead of keep_prob. Please ensure that this is intended.

# %%
model.add(tf.keras.layers.Dense(units=128, activation='relu', input_shape=(784, )))

# %%
model.add(tf.keras.layers.Dense(units=64, activation='relu'))

# %%
model.add(tf.keras.layers.Dropout(0.2))

# %%
model.add(tf.keras.layers.Dense(units=10, activation='softmax'))

# %%
model.compile(optimizer='adam', loss='sparse_categorical_crossentropy', metrics=['sparse_categorical_accuracy'])

# %%
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense (Dense)                (None, 32)                25120
# _________________________________________________________________
# dropout (Dropout)            (None, 32)                0
# _________________________________________________________________
# dense_1 (Dense)              (None, 64)                2112
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 64)                0
# _________________________________________________________________
# dense_2 (Dense)              (None, 128)               8320
# _________________________________________________________________
# dense_3 (Dense)              (None, 10)                1290
# _________________________________________________________________
# dense_4 (Dense)              (None, 128)               1408
# _________________________________________________________________
# dense_5 (Dense)              (None, 64)                8256
# _________________________________________________________________
# dropout_2 (Dropout)          (None, 64)                0
# _________________________________________________________________
# dense_6 (Dense)              (None, 10)                650
# =================================================================
# Total params: 47,156
# Trainable params: 47,156
# Non-trainable params: 0
# _________________________________________________________________

# %%
model.fit(X_train, y_train, epochs=10)
# Out:
# Train on 60000 samples
# Epoch 1/10
# WARNING:tensorflow:Large dropout rate: 0.6 (>0.5). In TensorFlow 2.x, dropout() uses dropout rate instead of keep_prob. Please ensure that this is intended.
# WARNING:tensorflow:Large dropout rate: 0.6 (>0.5). In TensorFlow 2.x, dropout() uses dropout rate instead of keep_prob. Please ensure that this is intended.
# 60000/60000 [==============================] - 4s 68us/sample - loss: 1.3612 - sparse_categorical_accuracy: 0.4105
# Epoch 2/10
# 60000/60000 [==============================] - 3s 52us/sample - loss: 0.9633 - sparse_categorical_accuracy: 0.6101
# Epoch 3/10
# 60000/60000 [==============================] - 3s 56us/sample - loss: 0.8599 - sparse_categorical_accuracy: 0.6621
# Epoch 4/10
# 60000/60000 [==============================] - 3s 54us/sample - loss: 0.8114 - sparse_categorical_accuracy: 0.6801
# Epoch 5/10
# 60000/60000 [==============================] - 4s 58us/sample - loss: 0.7684 - sparse_categorical_accuracy: 0.6975
# Epoch 6/10
# 60000/60000 [==============================] - 3s 54us/sample - loss: 0.7443 - sparse_categorical_accuracy: 0.7091
# Epoch 7/10
# 60000/60000 [==============================] - 3s 54us/sample - loss: 0.7310 - sparse_categorical_accuracy: 0.7188
# Epoch 8/10
# 60000/60000 [==============================] - 3s 54us/sample - loss: 0.7198 - sparse_categorical_accuracy: 0.7280
# Epoch 9/10
# 60000/60000 [==============================] - 3s 56us/sample - loss: 0.6995 - sparse_categorical_accuracy: 0.7407
# Epoch 10/10
# 60000/60000 [==============================] - 3s 53us/sample - loss: 0.7009 - sparse_categorical_accuracy: 0.7438

# %%
test_loss, test_accuracy = model.evaluate(X_test, y_test)
# Out:
# 10000/1 [======================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================= ...

# %%
model_json = model.to_json()
with open("fashion_model.json1", "w") as json_file:
    json_file.write(model_json)

# %%
model.save_weights("fashion_model1.h5")
