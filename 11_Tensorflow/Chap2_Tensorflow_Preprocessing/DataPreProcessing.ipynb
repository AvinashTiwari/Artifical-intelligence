# %%
import numpy as np
import datetime
import tensorflow as tf
from tensorflow.keras.datasets import fashion_mnist

# %%
tf.__version__
# Out:
# '2.0.0'

# %%
(X_train, y_train), (X_test, y_test) = fashion_mnist.load_data()

# %%
X_train = X_train / 255.0

# %%
X_test = X_test / 255.0

# %%
X_train = X_train.reshape(-1, 28*28)

# %%
X_train.shape
# Out:
# (60000, 784)

# %%
X_test = X_test.reshape(-1, 28*28)

# %%
model = tf.keras.models.Sequential()

# %%
model.add(tf.keras.layers.Dense(units=128, activation='relu', input_shape=(784, )))

# %%
model.add(tf.keras.layers.Dropout(0.2))

# %%
model.add(tf.keras.layers.Dense(units=10, activation='softmax'))

# %%
model.compile(optimizer='adam', loss='sparse_categorical_crossentropy', metrics=['sparse_categorical_accuracy'])

# %%
model.fit(X_train, y_train, epochs=5)
# Out:
# Train on 60000 samples
# Epoch 1/5
# 60000/60000 [==============================] - 3s 56us/sample - loss: 0.5293 - sparse_categorical_accuracy: 0.8134
# Epoch 2/5
# 60000/60000 [==============================] - 3s 45us/sample - loss: 0.3986 - sparse_categorical_accuracy: 0.8566
# Epoch 3/5
# 60000/60000 [==============================] - 3s 47us/sample - loss: 0.3638 - sparse_categorical_accuracy: 0.8669
# Epoch 4/5
# 60000/60000 [==============================] - 3s 47us/sample - loss: 0.3426 - sparse_categorical_accuracy: 0.8752
# Epoch 5/5
# 60000/60000 [==============================] - 3s 53us/sample - loss: 0.3294 - sparse_categorical_accuracy: 0.8776

# %%
test_loss, test_accuracy = model.evaluate(X_test, y_test)
# Out:
# 10000/1 [======================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================= ...

# %%
print("Test accuracy: {}".format(test_accuracy))
# Out:
# Test accuracy: 0.8694999814033508

# %%
model_json = model.to_json()
with open("fashion_model.json", "w") as json_file:
    json_file.write(model_json)

# %%
model.save_weights("fashion_model.h5")

# %%
#https://colab.research.google.com/drive/1tj02zPuUkkbLob1oo63f9TliYj5DQHA3#scrollTo=R0ZOVcC498Mp
